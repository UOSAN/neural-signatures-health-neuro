# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# load mask
from nilearn import image
from nilearn.masking import compute_epi_mask

logistic = image.load_img('/Users/danicosme/Documents/code/sanlab/neural-signatures-health-neuro/neural_signatures/multivariate.nii.gz')
reg_look = image.load_img('/Users/danicosme/Documents/code/sanlab/neural-signatures-health-neuro/neural_signatures/univariate_regulate_look.nii.gz')
reg_rest = image.load_img('/Users/danicosme/Documents/code/sanlab/neural-signatures-health-neuro/neural_signatures/univariate_regulate_baseline.nii.gz')

from nilearn import plotting
logistic_plot = plotting.plot_glass_brain(logistic, display_mode='lyrz', colorbar=True, plot_abs=False, cmap=plotting.cm.ocean_hot)
reg_look_plot = plotting.plot_glass_brain(reg_look, display_mode='lyrz', colorbar=True, plot_abs=False, cmap=plotting.cm.ocean_hot)
reg_rest_plot = plotting.plot_glass_brain(reg_rest, display_mode='lyrz', colorbar=True, plot_abs=False, cmap=plotting.cm.ocean_hot)

# %%
logistic_plot_sag = plotting.plot_glass_brain(logistic, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
reg_look_plot_sag = plotting.plot_glass_brain(reg_look, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
reg_rest_plot_sag = plotting.plot_glass_brain(reg_rest, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)

# %%
logistic_plot.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/logistic_plot.png', dpi=300)
reg_look_plot.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/reg_look_plot.png', dpi=300)
reg_rest_plot.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/reg_rest_plot.png', dpi=300)

logistic_plot_sag.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/logistic_plot_sag.png', dpi=300)
reg_look_plot_sag.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/reg_look_plot_sag.png', dpi=300)
reg_rest_plot_sag.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/reg_rest_plot_sag.png', dpi=300)

# %%
# look and regulate conditions
s1r = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/fx_cons/CH001_reappraiseCraveAll.nii.gz')
s1l = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/fx_cons/CH001_lookCraveAll.nii.gz')
s2r = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/fx_cons/DK003_reappraiseCraveAll.nii.gz')
s2l = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/fx_cons/DK003_lookCraveAll.nii.gz')
s3r = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/fx_cons/ET001_reappraiseCraveAll.nii.gz')
s3l = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/fx_cons/ET001_lookCraveAll.nii.gz')

s1_r = plotting.plot_glass_brain(s1r, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s1_l = plotting.plot_glass_brain(s1l, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s2_r = plotting.plot_glass_brain(s2r, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s2_l = plotting.plot_glass_brain(s2l, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s3_r = plotting.plot_glass_brain(s3r, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s3_l = plotting.plot_glass_brain(s3l, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)

s1_r.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s1_r.png', dpi=300)
s1_l.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s1_l.png', dpi=300)
s2_r.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s2_r.png', dpi=300)
s2_l.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s2_l.png', dpi=300)
s3_r.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s3_r.png', dpi=300)
s3_l.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s3_l.png', dpi=300)

# %%
# look and regulate conditions
s1t1 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1001/beta_0001.nii')
s1t2 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1001/beta_0002.nii')
s1t3 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1001/beta_0003.nii')
s2t1 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1002/beta_0001.nii')
s2t2 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1002/beta_0002.nii')
s2t3 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1002/beta_0003.nii')
s3t1 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1004/beta_0001.nii')
s3t2 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1004/beta_0003.nii')
s3t3 = image.load_img('/Users/danicosme/Documents/code/sanlab/NSC_scripts/data/picture_betaseries/sub-CHIVES1004/beta_0004.nii')

s1_t1 = plotting.plot_glass_brain(s1t1, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s1_t2 = plotting.plot_glass_brain(s1t2, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s1_t3 = plotting.plot_glass_brain(s1t3, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s2_t1 = plotting.plot_glass_brain(s2t1, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s2_t2 = plotting.plot_glass_brain(s2t2, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s2_t3 = plotting.plot_glass_brain(s2t3, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s3_t1 = plotting.plot_glass_brain(s3t1, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s3_t2 = plotting.plot_glass_brain(s3t2, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)
s3_t3 = plotting.plot_glass_brain(s3t3, display_mode='x', plot_abs=False, cmap=plotting.cm.ocean_hot)

s1_t1.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s1_t1.png', dpi=300)
s1_t2.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s1_t2.png', dpi=300)
s1_t3.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s1_t3.png', dpi=300)
s2_t1.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s2_t1.png', dpi=300)
s2_t2.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s2_t2.png', dpi=300)
s2_t3.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s2_t3.png', dpi=300)
s3_t1.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s3_t1.png', dpi=300)
s3_t2.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s3_t2.png', dpi=300)
s3_t3.savefig('/Users/danicosme/Dropbox (PfeiBer Lab)/Devaluation/Papers/SCAN_health_neuro/brains/s3_t3.png', dpi=300)
